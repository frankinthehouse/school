# %%
# IMPORT 引用 PYTHON的模組
import requests
import bs4
import openpyxl

    #開execl 的新工作區
wb=openpyxl.Workbook()

    #開工作區的新分頁
ws=wb.active

ws["A1"]="職缺名稱"
ws["B1"]="職缺連結"
ws["C1"]="公司名稱"
ws["D1"]="工作地區"
ws["E1"]="薪資待遇"
ws["F1"]="給薪方式"
ws["G1"]="薪資下限"
ws["H1"]="薪資上限"

#ws.append(["大數據工程師","https://8.8.8.8","鴻海","台北市","待遇面議"])

#   #存檔
#wb.save("py_execl_test_20240629.xlsx")

# 使用模組裡面的工具，用 " . " REQUESTS.GET 
                  # 網址 # 
res=requests.get("https://www.104.com.tw/jobs/search/?ro=0&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=1&asc=0&page=1&mode=s&jobsource=index_s&langFlag=0&langStatus=0&recommendJob=1&hotJob=1")

soup=bs4.BeautifulSoup(res.text)
#要查看 返回的內容詳情，後面加 .text
#print(soup.find_all("a",class_="js-job-link")[0].text)

soup_title=soup.find_all("article")
#print(soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"))

page=1
while soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
    for go in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        a=go.a.text
        b="http:"+go.a["href"]
        c=go.select("a")[1].text.strip()
        d=go.find("ul",class_="b-list-inline b-clearfix job-list-intro b-content").li.text
        e=go.find("div",class_="job-list-tag b-content").find(class_="b-tag--default").text
        payday=e[0:2]
        #清洗多餘中文符號
        money=""
        for clean in e:
            if clean.isdigit() or clean=="~":
                money+=clean
            #區分薪資範圍
        if "~" in money:
            high=money[:money.find("~")]
            low=money[money.find("~")+1:]
        else:
            high=money
            low=money
            
        if  high and low !=[]:  
            high=int(high)
            low=int(low)
        else:
            high=high
            low=low
            #print(high,low)
            #print(payday,money)
        f=payday
        g=high
        h=low
        ws.append([a,b,c,d,e,f,g,h])
         #給薪方式
        
    page+=1
    res=requests.get("https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page="+str(page)+"&mode=s&jobsource=index_s&langFlag=0&langStatus=0&recommendJob=1&hotJob=1") 
    soup=bs4.BeautifulSoup(res.text)
    print("=================================================")
    print("正在爬取第"+str(page)+"頁")
    print("=================================================")
    wb.save("py_execl_20240629.xlsx")
# Out:
# =================================================
# 正在爬取第2頁
# =================================================
# =================================================
# 正在爬取第3頁
# =================================================
# =================================================
# 正在爬取第4頁
# =================================================
# =================================================
# 正在爬取第5頁
# =================================================
# =================================================
# 正在爬取第6頁
# =================================================
# =================================================
# 正在爬取第7頁
# =================================================
# =================================================
# 正在爬取第8頁
# =================================================
# =================================================
# 正在爬取第9頁
# =================================================
# =================================================
# 正在爬取第10頁
# =================================================
# =================================================
# 正在爬取第11頁
# =================================================
# =================================================
# 正在爬取第12頁
# =================================================
# =================================================
# 正在爬取第13頁
# =================================================
# =================================================
# 正在爬取第14頁
# =================================================
# =================================================
# 正在爬取第15頁
# =================================================
# =================================================
# 正在爬取第16頁
# =================================================
# =================================================
# 正在爬取第17頁
# =================================================
# =================================================
# 正在爬取第18頁
# =================================================
# =================================================
# 正在爬取第19頁
# =================================================
# =================================================
# 正在爬取第20頁
# =================================================
# =================================================
# 正在爬取第21頁
# =================================================
# =================================================
# 正在爬取第22頁
# =================================================
# =================================================
# 正在爬取第23頁
# =================================================
# =================================================
# 正在爬取第24頁
# =================================================
# =================================================
# 正在爬取第25頁
# =================================================
# =================================================
# 正在爬取第26頁
# =================================================
# =================================================
# 正在爬取第27頁
# =================================================
# =================================================
# 正在爬取第28頁
# =================================================
# =================================================
# 正在爬取第29頁
# =================================================
# =================================================
# 正在爬取第30頁
# =================================================
# =================================================
# 正在爬取第31頁
# =================================================
# =================================================
# 正在爬取第32頁
# =================================================
# =================================================
# 正在爬取第33頁
# =================================================
# =================================================
# 正在爬取第34頁
# =================================================
# =================================================
# 正在爬取第35頁
# =================================================
# =================================================
# 正在爬取第36頁
# =================================================
# =================================================
# 正在爬取第37頁
# =================================================
# =================================================
# 正在爬取第38頁
# =================================================
# =================================================
# 正在爬取第39頁
# =================================================
# =================================================
# 正在爬取第40頁
# =================================================
# =================================================
# 正在爬取第41頁
# =================================================
# =================================================
# 正在爬取第42頁
# =================================================
# =================================================
# 正在爬取第43頁
# =================================================
# =================================================
# 正在爬取第44頁
# =================================================
# =================================================
# 正在爬取第45頁
# =================================================
# =================================================
# 正在爬取第46頁
# =================================================
# =================================================
# 正在爬取第47頁
# =================================================
# =================================================
# 正在爬取第48頁
# =================================================
# =================================================
# 正在爬取第49頁
# =================================================
# =================================================
# 正在爬取第50頁
# =================================================
# =================================================
# 正在爬取第51頁
# =================================================
# =================================================
# 正在爬取第52頁
# =================================================
# =================================================
# 正在爬取第53頁
# =================================================
# =================================================
# 正在爬取第54頁
# =================================================
# =================================================
# 正在爬取第55頁
# =================================================
# =================================================
# 正在爬取第56頁
# =================================================
# =================================================
# 正在爬取第57頁
# =================================================
# =================================================
# 正在爬取第58頁
# =================================================
# =================================================
# 正在爬取第59頁
# =================================================
# =================================================
# 正在爬取第60頁
# =================================================
# =================================================
# 正在爬取第61頁
# =================================================
# =================================================
# 正在爬取第62頁
# =================================================
# =================================================
# 正在爬取第63頁
# =================================================
# =================================================
# 正在爬取第64頁
# =================================================
# =================================================
# 正在爬取第65頁
# =================================================
# =================================================
# 正在爬取第66頁
# =================================================
# =================================================
# 正在爬取第67頁
# =================================================
# =================================================
# 正在爬取第68頁
# =================================================
# =================================================
# 正在爬取第69頁
# =================================================
# =================================================
# 正在爬取第70頁
# =================================================
# =================================================
# 正在爬取第71頁
# =================================================
# =================================================
# 正在爬取第72頁
# =================================================
# =================================================
# 正在爬取第73頁
# =================================================
# =================================================
# 正在爬取第74頁
# =================================================
# =================================================
# 正在爬取第75頁
# =================================================
# =================================================
# 正在爬取第76頁
# =================================================
# =================================================
# 正在爬取第77頁
# =================================================
# =================================================
# 正在爬取第78頁
# =================================================
# =================================================
# 正在爬取第79頁
# =================================================
# =================================================
# 正在爬取第80頁
# =================================================
# =================================================
# 正在爬取第81頁
# =================================================
# =================================================
# 正在爬取第82頁
# =================================================
# =================================================
# 正在爬取第83頁
# =================================================
# =================================================
# 正在爬取第84頁
# =================================================
# =================================================
# 正在爬取第85頁
# =================================================
# =================================================
# 正在爬取第86頁
# =================================================
# =================================================
# 正在爬取第87頁
# =================================================
# =================================================
# 正在爬取第88頁
# =================================================
# =================================================
# 正在爬取第89頁
# =================================================
# =================================================
# 正在爬取第90頁
# =================================================
# =================================================
# 正在爬取第91頁
# =================================================
# =================================================
# 正在爬取第92頁
# =================================================
# =================================================
# 正在爬取第93頁
# =================================================
# =================================================
# 正在爬取第94頁
# =================================================
# =================================================
# 正在爬取第95頁
# =================================================
# =================================================
# 正在爬取第96頁
# =================================================
# =================================================
# 正在爬取第97頁
# =================================================
# =================================================
# 正在爬取第98頁
# =================================================
# =================================================
# 正在爬取第99頁
# =================================================
# =================================================
# 正在爬取第100頁
# =================================================
# =================================================
# 正在爬取第101頁
# =================================================
# =================================================
# 正在爬取第102頁
# =================================================
# =================================================
# 正在爬取第103頁
# =================================================
# =================================================
# 正在爬取第104頁
# =================================================
# =================================================
# 正在爬取第105頁
# =================================================
# =================================================
# 正在爬取第106頁
# =================================================
# =================================================
# 正在爬取第107頁
# =================================================
# =================================================
# 正在爬取第108頁
# =================================================
# =================================================
# 正在爬取第109頁
# =================================================
# =================================================
# 正在爬取第110頁
# =================================================
# =================================================
# 正在爬取第111頁
# =================================================
